# %%
import time
import requests
from bs4 import BeautifulSoup
url = 'https://apteka-ot-sklada.ru/catalog/medikamenty-i-bady%2Fantibiotiki?start=0'# создать переменную для ссылки на сайт 
cookies = {'citi': '92'}
request = requests.get(url, cookies) #запрос на сервер
soup = BeautifulSoup(request.text,'lxml')# создали суп объект для того что бы делать поиск 
items = soup.find('div',{'class':'goods-grid__inner'}).find_all('div',{'class':'ui-card ui-card_size_default ui-card_outlined goods-card goods-grid__cell goods-grid__cell_size_3'}) # нашли тег по классу
#print(len(items))
for item in items: 
#     print(item.prettify())
 
    timestamp = int(time.time())
    RPC = item.find("div", 
                    {"class":"goods-card__name text text_size_default text_weight_medium"}
                   ).find("a")["href"].split("_")[-1]
    
    url = "https://apteka-ot-sklada.ru"+item.find("div", 
                    {"class":"goods-card__name text text_size_default text_weight_medium"}
                   ).find("a")["href"]
    
    title = item.find('span',{'itemprop':'name'}).text
    marketing_tags = [i.strip() for i in item.find('ul',{'class':'goods-tags__list goods-tags__list_direction_vertical'}).text.split('\n') if i.strip()]
    
    brand = item.find('div',{'class':'goods-card__producer text'}).find("span", {"itemtype":"legalName"}).text
    
    section = soup.find('ul',{'class':'ui-breadcrumbs__list'}).find_all("li")
    section = [item.text.strip() for item in section]
    
    price_data = {"current": item.find("span", {"class":"goods-card__cost text text_size_title text_weight_bold"}
                                      ).text.replace("₽", "").replace("\n", "").strip(),
                  "original": item.find("span", {"class":"goods-card__cost text text_size_title text_weight_bold"}
                                      ).text.replace("₽", "").replace("\n", "").strip(),
                  "sale_tag": None
                 
                 }
    
    stock = {"in_stock": item.find("div", {"class":"goods-card__cost-area text"}
                                      ).find("link")["href"],
             "count": 0
                 
                 }
    
    assets = {
        "main_image": "https://apteka-ot-sklada.ru" + item.find("img")["src"],
        "set_images": ["https://apteka-ot-sklada.ru" + item.find("img")["src"]],  # {list of str} Список больших изображений товара
        "view360": [None],  # {list of str}
        "video": [None]  # {list of str} 
    }
    
    metadata = {
        "__description": "",  # {str} Описание товар
    }
    
    
#     original = item.find('span',{'class':'goods-card__cost text text_size_title text_weight_bold'}).text
    
    
    print(f"{timestamp=}")
    print(f"{RPC=}")
    print(f"{url=}")
    print(f"{title=}")
    print(f"{marketing_tags=}")
    print(f"{brand=}")
    print(f"{section=}")
    
    print(f"{price_data=}")
    print(f"{stock=}")
    print(f"{assets=}")
#     print(f"{original=}")

#     print(item)
    break
# Out:
# timestamp=1663781712
# RPC='57523157'
# url='https://apteka-ot-sklada.ru/catalog/Linkomitsina-gidrohlorid-amp-30_-1ml-N-10_57523157'
# title='Линкомицина гидрохлорид амп 30% 1мл N 10'
# marketing_tags=['по рецепту', 'STOP Цена']
# brand='РУП Белмедпрепараты'
# section=['Главная', 'Каталог', 'Медикаменты и БАДы', 'Антибиотики']
# price_data={'current': '94.00', 'original': '94.00', 'sale_tag': None}
# stock={'in_stock': 'http://schema.org/InStock', 'count': 0}
# assets={'main_image': 'https://apteka-ot-sklada.ru/images/goods/57523157.jpg', 'set_images': ['https://apteka-ot-sklada.ru/images/goods/57523157.jpg'], 'view360': [None], 'video': [None]}

# %%
request = requests.get("https://apteka-ot-sklada.ru/catalog/kosmetika/dlya-muzhchin?start=12")

# %%
request.text
# Out:
# '<!doctype html>\r\n<html data-n-head-ssr lang="ru" data-n-head="%7B%22lang%22:%7B%22ssr%22:%22ru%22%7D%7D">\r\n  <head >\r\n    <title>Каталог лекарств купить по низким ценам, заказ на Apteka-ot-sklada.ru</title><meta data-n-head="ssr" charset="utf-8"><meta data-n-head="ssr" name="format-detection" content="telephone=no"><meta data-n-head="ssr" name="staticurl" content="/userfiles" value="/userfiles"><meta data-n-head="ssr" name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><meta data-n-head="ssr" property="og:site_name" content="Аптека от склада"><meta data-n-head="ssr" data-hid="og:type" property="og:type" content="website"><meta data-n-head="ssr" data-hid="og:title" property="og:title" content="Аптека от склада"><meta data-n-head="ssr" data-hid="og:image" property="og:image" content="/userfiles/site/favicon-120x120.png"><meta data-n-head="ssr" name="msapplication-TileColor" content="#633ba5"><meta data-n-head="ssr" name="theme-color" content="#633ba5"
# ...

# %%
def parse_detailed_information(html):
    soup = BeautifulSoup(html, features="lxml")
    
    main_body = soup.find("div", {"class":"ui-collapsed-content__content"})
    
    text = main_body.text.split("\n")
    
    
    return_dict = {}
    for key, value in zip(*[iter(text)]*2):
        return_dict[key] = value
    
    
    return return_dict

# %%
parse_detailed_information(request.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 parse_detailed_information(request.text)
#
# Input In [67], in parse_detailed_information(html)
#       2 soup = BeautifulSoup(html, features="lxml")
#       4 main_body = soup.find("div", {"class":"ui-collapsed-content__content"})
# ----> 6 text = main_body.text.split("\n")
#       9 return_dict = {}
#      10 for key, value in zip(*[iter(text)]*2):
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
def apteka(html):
    soup = BeautifulSoup(html,'lxml')# создали суп объект для того что бы делать поиск 
    items = soup.find('div',{'class':'goods-grid__inner'}).find_all('div',{'class':'ui-card ui-card_size_default ui-card_outlined goods-card goods-grid__cell goods-grid__cell_size_3'}) # нашли тег по классу
    return_list = []
    #print(len(items))
    for item in items: 
        timestamp = int(time.time())
        RPC = item.find("div", 
                        {"class":"goods-card__name text text_size_default text_weight_medium"}
                       ).find("a")["href"].split("_")[-1]

        url = "https://apteka-ot-sklada.ru"+item.find("div", 
                        {"class":"goods-card__name text text_size_default text_weight_medium"}
                       ).find("a")["href"]

        title = item.find('span',{'itemprop':'name'}).text
        marketing_tags = [i.strip() for i in item.find('ul',{'class':'goods-tags__list goods-tags__list_direction_vertical'}).text.split('\n') if i.strip()]

        brand = item.find('div',{'class':'goods-card__producer text'}).find("span", {"itemtype":"legalName"}).text

        section = soup.find('ul',{'class':'ui-breadcrumbs__list'}).find_all("li")
        section = [item.text.strip() for item in section]

        price_data = {"current": item.find("span", {"class":"goods-card__cost text text_size_title text_weight_bold"}
                                          ).text.replace("₽", "").replace("\n", "").strip(),
                      "original": item.find("span", {"class":"goods-card__cost text text_size_title text_weight_bold"}
                                          ).text.replace("₽", "").replace("\n", "").strip(),
                      "sale_tag": None

                     }

        stock = {"in_stock": item.find("div", {"class":"goods-card__cost-area text"}
                                          ).find("link")["href"],
                 "count": 0

                     }

        assets = {
            "main_image": "https://apteka-ot-sklada.ru" + item.find("img")["src"],
            "set_images": ["https://apteka-ot-sklada.ru" + item.find("img")["src"]],  # {list of str} Список больших изображений товара
            "view360": [None],  # {list of str}
            "video": [None]  # {list of str} 
        }

        metadata = {
            "__description": "",  # {str} Описание товар
        }
        return_list.append({'timestamp':timestamp,
                            "RPC": RPC,
                            "url": url,
                            'marketing_tags':marketing_tags,
                            'title':title,
                            'section':section,
                            'brand':brand,
                            'price_data': price_data,
                            "stock": stock,
                            "assests": assets,
                           "metadata": metadata}
                          )
#         break
    return return_list

# %%
request = requests.get("https://apteka-ot-sklada.ru/catalog/kosmetika/dlya-muzhchin?start=0", cookies= {'city': '92'})

# %%
request.text
# Out:
# '<!doctype html>\r\n<html data-n-head-ssr lang="ru" data-n-head="%7B%22lang%22:%7B%22ssr%22:%22ru%22%7D%7D">\r\n  <head >\r\n    <title>Каталог лекарств купить по низким ценам, заказ на Apteka-ot-sklada.ru</title><meta data-n-head="ssr" charset="utf-8"><meta data-n-head="ssr" name="format-detection" content="telephone=no"><meta data-n-head="ssr" name="staticurl" content="/userfiles" value="/userfiles"><meta data-n-head="ssr" name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><meta data-n-head="ssr" property="og:site_name" content="Аптека от склада"><meta data-n-head="ssr" data-hid="og:type" property="og:type" content="website"><meta data-n-head="ssr" data-hid="og:title" property="og:title" content="Аптека от склада"><meta data-n-head="ssr" data-hid="og:image" property="og:image" content="/userfiles/site/favicon-120x120.png"><meta data-n-head="ssr" name="msapplication-TileColor" content="#633ba5"><meta data-n-head="ssr" name="theme-color" content="#633ba5"
# ...

# %%
apteka(request.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [75], in <cell line: 1>()
# ----> 1 apteka(request.text)
#
# Input In [70], in apteka(html)
#      21 section = soup.find('ul',{'class':'ui-breadcrumbs__list'}).find_all("li")
#      22 section = [item.text.strip() for item in section]
# ---> 24 price_data = {"current": item.find("span", {"class":"goods-card__cost text text_size_title text_weight_bold"}
#      25                                   ).text.replace("₽", "").replace("\n", "").strip(),
#      26               "original": item.find("span", {"class":"goods-card__cost text text_size_title text_weight_bold"}
#      27                                   ).text.replace("₽", "").replace("\n", "").strip(),
#      28               "sale_tag": None
#      29
#      30              }
#      32 stock = {"in_stock": item.find("div", {"class":"goods-card__cost-area text"}
# ...
